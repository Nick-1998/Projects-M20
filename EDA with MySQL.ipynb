# %%
# !pip install mysql-connector-python

# %%
# importing module
import mysql.connector

# %%
import pandas as pd
con=mysql.connector.connect(
    host = "localhost",
    port = 3306,
    user="root",
    password = "Niks1998@",
    database= "students")

df=pd.read_sql_query("Select  * from studmarks",con)
df
df.head()
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M    5/4/1988     55       45         56       87       21
# 1    Suresh      M    4/5/1987     75       96         78       64       90
# 2    Ramesh      M  25-05-1989     25       54         89       76       95
# 3   Jessica      F   12/8/1990     78       96         86       63       54
# 4  Jennifer      F    2/9/1989     58       96         78       46       96
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# 3         89       75      45
# 4         77       83      53

# %%
# importing libarieries
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# last five
df.tail()
# Out:
#      Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 5    Annu      F    5/4/1988     45       87         52       89       55
# 6   pooja      F    4/5/1987     55       64         61       58       75
# 7  Ritesh      M  25-05-1989     54       76         87       56       25
# 8   Farha      F   12/8/1990     55       63         89       75       78
# 9  Mukesh      M    2/9/1989     96       46         77       83       58
#
#    Economics  History  Civics
# 5         89       87      52
# 6         58       64      61
# 7         56       76      87
# 8         75       63      89
# 9         83       46      77

# %%
df.sample()
# Out:
#      Name Gender       DOB  Maths  Physics  Chemistry  English  Biology  \
# 9  Mukesh      M  2/9/1989     96       46         77       83       58
#
#    Economics  History  Civics
# 9         83       46      77

# %%
# Checking the skewnsess
df.skew()
# Out:
# Maths        0.246964
# Physics     -0.045336
# Chemistry   -0.746462
# English     -0.131222
# Biology     -0.496446
# Economics   -0.245555
# History     -0.131222
# Civics      -1.332448
# dtype: float64

# %%
# Checking the null values
df.isnull().sum()
# Out:
# Name         0
# Gender       0
# DOB          0
# Maths        0
# Physics      0
# Chemistry    0
# English      0
# Biology      0
# Economics    0
# History      0
# Civics       0
# dtype: int64

# %% [markdown]
# '''
# No null values are present. Cool
# '''

# %%
df = df.rename(columns={'Name':'name','Gender':'gender','DOB':'dob','Maths':'maths','Physics':'physics','Chemistry':'chemistry','English':'english','Biology':'biology','Economics':'economics','History':'history','Civics':'civics'});

# %%
df
# Out:
#        name gender         dob  maths  physics  chemistry  english  biology  \
# 0      John      M    5/4/1988     55       45         56       87       21
# 1    Suresh      M    4/5/1987     75       96         78       64       90
# 2    Ramesh      M  25-05-1989     25       54         89       76       95
# 3   Jessica      F   12/8/1990     78       96         86       63       54
# 4  Jennifer      F    2/9/1989     58       96         78       46       96
# 5      Annu      F    5/4/1988     45       87         52       89       55
# 6     pooja      F    4/5/1987     55       64         61       58       75
# 7    Ritesh      M  25-05-1989     54       76         87       56       25
# 8     Farha      F   12/8/1990     55       63         89       75       78
# 9    Mukesh      M    2/9/1989     96       46         77       83       58
#
#    economics  history  civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# ...

# %%
# Check the shape
df.shape
# Out:
# (10, 11)

# %%
df.info
# Out:
# <bound method DataFrame.info of        name gender         dob  maths  physics  chemistry  english  biology  \
# 0      John      M    5/4/1988     55       45         56       87       21
# 1    Suresh      M    4/5/1987     75       96         78       64       90
# 2    Ramesh      M  25-05-1989     25       54         89       76       95
# 3   Jessica      F   12/8/1990     78       96         86       63       54
# 4  Jennifer      F    2/9/1989     58       96         78       46       96
# 5      Annu      F    5/4/1988     45       87         52       89       55
# 6     pooja      F    4/5/1987     55       64         61       58       75
# 7    Ritesh      M  25-05-1989     54       76         87       56       25
# 8     Farha      F   12/8/1990     55       63         89       75       78
# 9    Mukesh      M    2/9/1989     96       46         77       83       58
#
#    economics  history  civics
# 0         52       89      65
# 1         61       58       2
# ...

# %%
df.describe()
# Out:
#            maths    physics  chemistry    english    biology  economics  \
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean   59.600000  72.300000  75.300000  69.700000  64.700000  72.700000
# std    19.460501  20.661559  14.000397  14.453373  26.998148  14.629119
# min    25.000000  45.000000  52.000000  46.000000  21.000000  52.000000
# 25%    54.250000  56.250000  65.000000  59.250000  54.250000  58.750000
# 50%    55.000000  70.000000  78.000000  69.500000  66.500000  76.000000
# 75%    70.750000  93.750000  86.750000  81.250000  87.000000  86.000000
# max    96.000000  96.000000  89.000000  89.000000  96.000000  89.000000
#
#          history   civics
# count  10.000000  10.0000
# mean   69.700000  60.5000
# std    14.453373  25.3432
# min    46.000000   2.0000
# 25%    59.250000  52.2500
# 50%    69.500000  63.0000
# 75%    81.250000  76.2500
# max    89.000000  89.0000

# %%
df.value_counts()
# Out:
# name      gender  dob         maths  physics  chemistry  english  biology  economics  history  civics
# pooja     F       4/5/1987    55     64       61         58       75       58         64       61        1
# Suresh    M       4/5/1987    75     96       78         64       90       61         58       2         1
# Ritesh    M       25-05-1989  54     76       87         56       25       56         76       87        1
# Ramesh    M       25-05-1989  25     54       89         76       95       87         56       74        1
# Mukesh    M       2/9/1989    96     46       77         83       58       83         46       77        1
# John      M       5/4/1988    55     45       56         87       21       52         89       65        1
# Jessica   F       12/8/1990   78     96       86         63       54       89         75       45        1
# Jennifer  F       2/9/1989    58     96       78         46       96       77         83       53        1
# ...

# %%
df.dtypes
# Out:
# name         object
# gender       object
# dob          object
# maths         int64
# physics       int64
# chemistry     int64
# english       int64
# biology       int64
# economics     int64
# history       int64
# civics        int64
# dtype: object

# %%
df.skew()
# Out:
# maths        0.246964
# physics     -0.045336
# chemistry   -0.746462
# english     -0.131222
# biology     -0.496446
# economics   -0.245555
# history     -0.131222
# civics      -1.332448
# dtype: float64

# %%
# Check outlier 
import seaborn as sns
sns.boxplot(x=df['civics'])

# %%
# Sorting data with number of maximum scored marks in Physics
# Visualize maxium scored cases in Phycics
import matplotlib.pyplot as plt
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x='name',y='physics',data=df,color = 'g')
plt.show()

# %%
df.corr()
# Out:
#               maths   physics  chemistry   english   biology  economics  \
# maths      1.000000  0.113354   0.076751 -0.064074 -0.146598   0.000312
# physics    0.113354  1.000000   0.117192 -0.562608  0.279638   0.191851
# chemistry  0.076751  0.117192   1.000000 -0.409680  0.318032   0.235390
# english   -0.064074 -0.562608  -0.409680  1.000000 -0.330844   0.237577
# biology   -0.146598  0.279638   0.318032 -0.330844  1.000000   0.370531
# economics  0.000312  0.191851   0.235390  0.237577  0.370531   1.000000
# history   -0.320846  0.334082  -0.482710 -0.038775 -0.456131  -0.164953
# civics    -0.274629 -0.643266   0.210908  0.186705 -0.330060   0.043905
#
#             history    civics
# maths     -0.320846 -0.274629
# physics    0.334082 -0.643266
# chemistry -0.482710  0.210908
# english   -0.038775  0.186705
# biology   -0.456131 -0.330060
# economics -0.164953  0.043905
# history    1.000000 -0.048686
# civics    -0.048686  1.000000

# %%
sns.pairplot(df)
plt.show()

# %%
print('Percentage',df.gender.value_counts(normalize=True))
df.gender.value_counts(normalize=True).plot(kind='bar')
# Out:
# Percentage F    0.5
# M    0.5
# Name: gender, dtype: float64

# %%
# understand the maths marks with differents students
plt.figure(figsize=(10,10))
plt.plot(df['maths'], df['name'])

# %% [markdown]
# '''
# Mukesh have scored high marks in Maths (ie. it is kike 90)
# Maximum Marks - 50 Marks scored the sutdents are Pooja, Jennifer,Sureshand JOhn
# Minimum Marks - Ramesh  and Annu
# '''

# %%
# understand the english marks with differents students
plt.figure(figsize=(10,10))
plt.plot(df['english'], df['name'])
